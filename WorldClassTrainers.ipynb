# %% [markdown]
# # TODO: club numbers filter (while scraping)

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
def get_club_nums_list():
    ''' Returns a list of all possible club numbers from WorldClass page'''
    
    URL = "https://www.worldclass.ru/trainers"
    page = requests.get(URL)

    soup = BeautifulSoup(page.text, "html.parser")
    num_list = soup.find_all("option", attrs={"data-code": True})
    num_list = [num.attrs['value'] for num in num_list]
    
    return num_list

# %%
def get_clubs_strings(all_num_list, ratio=0.5):
    ''' 
    Returns two strings with club numbers divided by a comma.
    
        Parameters:
                    all_num_list (list): A list of all possible club numbers
                    ratio (float): Desired split (from 0 to 1) of numbers from all_num_list (begining from the first element)
                    
        Returns: 
                    clubs_string_first (str): String of numbers before the split
                    clubs_string_second (str): String of numbers after the split
                    
    '''
    
    num_list_first = all_num_list[:int(len(num_list) * ratio)]
    clubs_string_first = ",".join(num_list_first)
    
    num_list_second = all_num_list[int(len(num_list) * ratio):]
    clubs_string_second = ",".join(num_list_second)
    
    return clubs_string_first, clubs_string_second

# %%
all_num_list = get_club_nums_list()
clubs_string_first, clubs_string_second = get_clubs_strings(all_num_list)

# %%
def get_trainer_list(clubs_string, les_mills=False):
    '''
    Returns a list of trainers from clubs_string clubs.

            Parameters:
                    clubs_string (str): A string with club numbers divided by a comma (e.g. '1,2,3,4,5')
                    les_mills (bool): If True, list will contain only Les Mills programms trainers

            Returns:
                    trainers_list (list): A list of (name, rating, position, link) tuples
                    
    '''
    
    # building URL based on arguments
    URL = "https://www.worldclass.ru/trainers/?club=" + clubs_string
    URL = URL + "&programm[]=93&programm[]=programmy-les-mills" if les_mills else URL
    URL = URL + "&SHOWALL_1=1"
    
    page = requests.get(URL)
    
    soup = BeautifulSoup(page.text, "html.parser")
    
    # retrieving raw html format list of trainers from that page
    trainers_list = soup.find_all("div", class_="trainers__item")
    
    # building tuples (name, rating, position, href_link) from raw list
    trainers_list = [(trainer.find(class_="staff-card__name").text, trainer.find(class_="span staff-card__rating-count"), 
                   trainer.find(class_="staff-card__text").text, trainer.find(class_ ="staff-card__name").attrs['href']) 
                  for trainer in trainers_list]
    
    # removing whitespaces from names, getting ratings (strings for now) if they exist (otherwise, assigning 0s), making links
    trainers_list = [(name.strip(), rating.text, position, "https://www.worldclass.ru" + link) if rating 
                  else (name, 0, position, "https://www.worldclass.ru" + link) 
                  for (name, rating, position, link) in trainers_list]
    
    # ratings to integers, dealing with bad ratings data (instances of "<l" instead of a number or None)
    trainers_list = [(name, int(rating), position, link) if rating != '<l' 
                  else (name, 0, position, link) 
                  for (name, rating, position, link) in trainers_list]
    
    return trainers_list

# %%
trainers_list_first = get_trainer_list(clubs_string_first)
trainers_list_second = get_trainer_list(clubs_string_second)

# %%
# appending two extracted lists, getting rid of duplicates
full_list = list(set(trainers_list_first + trainers_list_second))

# %%
# creating a dataframe with all our information from a list
df = pd.DataFrame(full_list, columns=['Тренер', 'Количество голосов', 'Должность', 'Ссылка'])

# %%
df.head()
# Out:
#              Тренер  Количество голосов  \
# 0   Александр Жиров                   0
# 1      Илья Никитин                   0
# 2  Татьяна Назарова                   1
# 3    Анна Хусаинова                   1
# 4   Сергей Новицкий                   4
#
#                                            Должность  \
# 0              Персональный тренер тренажерного зала
# 1              Персональный тренер тренажерного зала
# 2              Персональный тренер тренажерного зала
# 3  Супервайзер детского фитнеса. Мастер-тренер де...
# 4                Персональный тренер водных программ
#
#                                               Ссылка        Клубы
# 0  https://www.worldclass.ru/trainers/zhirov-alek...     [Триумф]
# 1   https://www.worldclass.ru/trainers/ilya-nikitin/     [Триумф]
# 2  https://www.worldclass.ru/trainers/nazarova-ta...     [Стачек]
# 3  https://www.worldclass.ru/trainers/khusainova-...     [Пресня]
# 4  https://www.worldclass.ru/trainers/novitskiy-s...  [Капитолий]

# %% [markdown]
# ## Extracting club names

# %%
def extract_club_names(URL):
    '''
    Returns a list of clubs from trainer's page (URL).

            Parameters:
                    URL (str): URL of some trainer's page
                    
            Returns:
                    club_list (list): A list of club names
                    
    '''
    page = requests.get(URL)
    soup = BeautifulSoup(page.text, "html.parser")
    
    club_list = soup.find_all(class_="club_link")
    club_list = [club.text for club in club_list]
    
    return club_list

# %%
# retrieving club names from the trainer's page --> new column
df['Клубы'] = df['Ссылка'].apply(extract_club_names)

# %% [markdown]
# ## Some manipulations with data

# %%
# sorting
df_sorted_rating = df.sort_values('Количество голосов', ascending=False)

# %%
# filtering by club names
club_list = ['Воробьевы горы', 'Капитолий']
df_by_clubs = df_sorted_rating[df_sorted_rating['Клубы'].apply(lambda x: any(club in x for club in club_list))]

# %%
df_by_clubs.head(60)
# Out:
#                         Тренер  Количество голосов  \
# 491             Мария Чернобай                  51
# 626        Валерия Кехриниотис                  20
# 792             Розалия Попова                  19
# 204           Эдуард Кунтудаев                  15
# 1047           Дмитрий Шаталов                  15
# 1126        Александр Атаманюк                  15
# 590               Карен Фероян                  11
# 220                Игорь Янкин                   9
# 747             Ирина Богатова                   8
# 152                Дмитрий Кок                   8
# 689              Павел Кивачук                   6
# 1130           Комольцев Денис                   5
# 1257       Валентина Глазунова                   5
# 353             Алексей Шконда                   5
# 4              Сергей Новицкий                   4
# 984             Артём Клименко                   4
# 944             Евгения Силина                   4
# 561               Анна Орехова                   3
# 692           Евгений Егоренко                   3
# 816            Ольга Лабовская                   3
# 659           Татьяна Данилова                   3
# 1020         Владислав Ковалев                   3
# 730             Ирина Денисова                   3
# 107            Ирина Привалова                   3
# 354          Альбина Черкасова                   3
# 43         Николай Пономаренко                   3
# 1258          Григорий Мелисов                   3
# 443            Наталья Баурова                   3
# 282              Андрей Спицын                   3
# 1342  Сергей Гольцев-Федорычев                   3
# 1379           Виктория Шубина                   2
# 1029           Максим Белоусов                   2
# 1387          Дмитрий Черкасов                   2
# 1472              Анна Бобкова                   2
# 831         Александр Гундарев                   2
# 606             Татьяна Гудель                   2
# 1105     Александр Брославский                   2
# 548             Софья Хаустова                   2
# 555              Дмитрий Родин                   2
# 671              Тимур Казаков                   2
# 1415          Валерия Стаценко                   1
# 1199           Алексей Романов                   1
# 1377       Александр Пивоваров                   1
# 1299          Татьяна Балашова                   1
# 1283             Ульяна Лобода                   1
# 1001             Мария Слепова                   1
# 1309          Татьяна Колодина                   1
# 600           Ольга Волосатова                   1
# 269           Ирина Терентьева                   1
# 667             Михаил Майоров                   1
# 229                Елена Бунос                   1
# 645             Юлия Усольцева                   1
# 413              Петр Лемешкин                   1
# 433              Андрей Шконда                   1
# 892         Виктория Коршунова                   1
# 10            Татьяна Чересова                   1
# 271       Владимир Пономаренко                   1
# 1263           Дарья Лемешкина                   0
# 343           Элина Журавлева                    0
# 1276     Эльвира Шайхутдинова                    0
#
#                                               Должность  \
# 491   Персональный тренер групповых программ, персон...
# 626                     Мастер-тренер тренажёрного зала
# 792                    Мастер-тренер групповых программ
# 204   Персональный тренер тренажерного зала, фитнес-...
# 1047                    Мастер-тренер Тренажерного зала
# 1126  Персональный тренер групповых программ, фитнес...
# 590                       Мастер-тренер Боевых искусств
# 220   Супервайзер, Мастер-тренер Групповых программ,...
# 747                   Фитнес-тренер Групповых программ
# 152                     Фитнес-тренер тренажерного зала
# 689   Персональный тренер Тренажерного зала, Персона...
# 1130              Персональный тренер тренажерного зала
# 1257                      Мастер-тренер водных программ
# 353   Мастер-тренер тренажерного зала. Мастер-тренер...
# 4                   Персональный тренер водных программ
# 984                       Фитнес-тренер водных программ
# 944                      Элит-тренер Групповых программ
# 561                    Мастер-тренер Групповых программ
# 692                Персональный тренер водных программ
# 816          Супервайзер, мастер-тренер водных программ
# 659   Фитнес-тренер Групповых программ, Фитнес-трене...
# 1020                      Мастер-тренер водных программ
# 730                      Мастер-тренер Детского фитнеса
# 107                    Фитнес-тренер Групповых программ
# 354                      Мастер-тренер программ по йоге
# 43    Мастер-тренер тренажерного зала, мастер-тренер...
# 1258  Супервайзер тренажерного зала. Персональный тр...
# 443                   Элит-тренер танцевальных программ
# 282               Персональный тренер тренажерного зала
# 1342  Мастер-тренер водных программ, мастер-тренер п...
# 1379  Директор направления «Триатлон», элит-тренер п...
# 1029                    Мастер-тренер тренажерного зала
# 1387                    Мастер-тренер тренажерного зала
# 1472  Мастер-тренер групповых программ, элит-тренер ...
# 831                       Фитнес-тренер Водных программ
# 606              Персональный тренер групповых программ
# 1105                 Мастер-тренер по боевым искусствам
# 548   Супервайзер детского фитнеса. Фитнес-тренер де...
# 555   Мастер-тренер тренажерного зала. Мастер-тренер...
# 671   Фитнес-тренер Водных программ, фитнес-тренер Д...
# 1415                    Мастер-тренер Тренажерного зала
# 1199  Персональный тренер Тренажерного зала, Персона...
# 1377                      Фитнес-тренер водных программ
# 1299      Супервайзер, мастер-тренер групповых программ
# 1283  Фитнес-менеджер, мастер-тренер по детскому фит...
# 1001            Персональный тренер по детскому фитнесу
# 1309  Элит-тренер Тренажерного зала, Элит-тренер Дет...
# 600         Супервайзер, Мастер-тренер Детского фитнеса
# 269   Супервайзер тренажерного зала, элит-тренер тре...
# 667          Супервайзер, Мастер-тренер Водных программ
# 229                      Мастер-тренер игровых программ
# 645                       Фитнес-тренер Водных программ
# 413                     Мастер-тренер тренажерного зала
# 433   Мастер-тренер тренажерного зала. Элит-тренер д...
# 892                      Фитнес-тренер Детского фитнеса
# 10                      Мастер-тренер тренажерного зала
# 271                     Мастер-тренер тренажерного зала
# 1263  Мастер-тренер по детскому фитнесу, персональны...
# 343                Персональный тренер детского фитнеса
# 1276  Фитнес-тренер Групповых программ, Фитнес-трене...
#
#                                                  Ссылка  \
# 491   https://www.worldclass.ru/trainers/chernobay-m...
# 626   https://www.worldclass.ru/trainers/valeriya-ke...
# 792   https://www.worldclass.ru/trainers/rozaliya-po...
# 204   https://www.worldclass.ru/trainers/kuntudaev-e...
# 1047  https://www.worldclass.ru/trainers/shatalov-dm...
# 1126  https://www.worldclass.ru/trainers/atamanyuk-a...
# 590   https://www.worldclass.ru/trainers/feroyan-kar...
# 220     https://www.worldclass.ru/trainers/yankin-igor/
# 747   https://www.worldclass.ru/trainers/bogatova-ir...
# 152     https://www.worldclass.ru/trainers/dmitriy-kok/
# 689   https://www.worldclass.ru/trainers/pavel-kivac...
# 1130  https://www.worldclass.ru/trainers/komoltsev-d...
# 1257  https://www.worldclass.ru/trainers/glazunova-v...
# 353   https://www.worldclass.ru/trainers/aleksey-shk...
# 4     https://www.worldclass.ru/trainers/novitskiy-s...
# 984   https://www.worldclass.ru/trainers/artyem-klim...
# 944   https://www.worldclass.ru/trainers/silina-evge...
# 561   https://www.worldclass.ru/trainers/orekhova-anna/
# 692   https://www.worldclass.ru/trainers/evgeniy-ego...
# 816   https://www.worldclass.ru/trainers/labovskaya-...
# 659   https://www.worldclass.ru/trainers/danilova-ta...
# 1020  https://www.worldclass.ru/trainers/kovalev-vla...
# 730   https://www.worldclass.ru/trainers/denisova-ir...
# 107   https://www.worldclass.ru/trainers/privalova-i...
# 354   https://www.worldclass.ru/trainers/albina-cher...
# 43    https://www.worldclass.ru/trainers/nikolay-pon...
# 1258  https://www.worldclass.ru/trainers/grigoriy-me...
# 443   https://www.worldclass.ru/trainers/natalya-bau...
# 282   https://www.worldclass.ru/trainers/spitsyn-and...
# 1342  https://www.worldclass.ru/trainers/sergey-golt...
# 1379  https://www.worldclass.ru/trainers/viktoriya-s...
# 1029  https://www.worldclass.ru/trainers/belousov-ma...
# 1387  https://www.worldclass.ru/trainers/cherkasov-d...
# 1472   https://www.worldclass.ru/trainers/anna-bobkova/
# 831   https://www.worldclass.ru/trainers/gundarev-al...
# 606   https://www.worldclass.ru/trainers/tatyana-gudel/
# 1105  https://www.worldclass.ru/trainers/broslavskiy...
# 548   https://www.worldclass.ru/trainers/khaustova-s...
# 555   https://www.worldclass.ru/trainers/dmitriy-rodin/
# 671   https://www.worldclass.ru/trainers/kazakov-timur/
# 1415  https://www.worldclass.ru/trainers/statsenko-v...
# 1199  https://www.worldclass.ru/trainers/romanov-ale...
# 1377  https://www.worldclass.ru/trainers/pivovarov-a...
# 1299  https://www.worldclass.ru/trainers/tatyana-bal...
# 1283  https://www.worldclass.ru/trainers/loboda-ulyana/
# 1001  https://www.worldclass.ru/trainers/slepova-mar...
# 1309  https://www.worldclass.ru/trainers/kolodina-ta...
# 600   https://www.worldclass.ru/trainers/volosatova-...
# 269   https://www.worldclass.ru/trainers/irina-teren...
# 667   https://www.worldclass.ru/trainers/mayorov-mik...
# 229     https://www.worldclass.ru/trainers/bunos-elena/
# 645   https://www.worldclass.ru/trainers/usoltseva-y...
# 413   https://www.worldclass.ru/trainers/lemeshkin-p...
# 433   https://www.worldclass.ru/trainers/andrey-shko...
# 892   https://www.worldclass.ru/trainers/viktoriya-k...
# 10    https://www.worldclass.ru/trainers/tatyana-che...
# 271   https://www.worldclass.ru/trainers/ponomarenko...
# 1263  https://www.worldclass.ru/trainers/darya-gonch...
# 343   https://www.worldclass.ru/trainers/zhuravleva-...
# 1276  https://www.worldclass.ru/trainers/shaykhutdin...
#
#                                                   Клубы
# 491                                         [Капитолий]
# 626                                         [Капитолий]
# 792                                         [Капитолий]
# 204                                         [Капитолий]
# 1047                                   [Воробьевы горы]
# 1126                                        [Капитолий]
# 590                                    [Воробьевы горы]
# 220                                    [Воробьевы горы]
# 747                                    [Воробьевы горы]
# 152                                         [Капитолий]
# 689                                    [Воробьевы горы]
# 1130                                        [Капитолий]
# 1257                                        [Капитолий]
# 353                                         [Капитолий]
# 4                                           [Капитолий]
# 984                                         [Капитолий]
# 944                                    [Воробьевы горы]
# 561                                    [Воробьевы горы]
# 692                                         [Капитолий]
# 816                                         [Капитолий]
# 659                                    [Воробьевы горы]
# 1020                                        [Капитолий]
# 730                                    [Воробьевы горы]
# 107                                    [Воробьевы горы]
# 354                                         [Капитолий]
# 43                                          [Капитолий]
# 1258                                   [Воробьевы горы]
# 443                    [Жуковка, Щелковский, Капитолий]
# 282                                         [Капитолий]
# 1342                                        [Капитолий]
# 1379  [Lady's, Варшавка, Власова, Город Столиц, Житн...
# 1029                                        [Капитолий]
# 1387                                        [Капитолий]
# 1472                                        [Капитолий]
# 831                                    [Воробьевы горы]
# 606                                         [Капитолий]
# 1105                     [Смоленский пассаж, Капитолий]
# 548                                         [Капитолий]
# 555                                         [Капитолий]
# 671                                    [Воробьевы горы]
# 1415                                   [Воробьевы горы]
# 1199                                   [Воробьевы горы]
# 1377                                   [Воробьевы горы]
# 1299                                        [Капитолий]
# 1283                                        [Капитолий]
# 1001                                        [Капитолий]
# 1309                                   [Воробьевы горы]
# 600                                    [Воробьевы горы]
# 269                                         [Капитолий]
# 667                                    [Воробьевы горы]
# 229                                         [Капитолий]
# 645                                    [Воробьевы горы]
# 413                                         [Капитолий]
# 433                                         [Капитолий]
# 892                                    [Воробьевы горы]
# 10                                          [Капитолий]
# 271                                         [Капитолий]
# 1263                                        [Капитолий]
# 343                                         [Капитолий]
# 1276                                   [Воробьевы горы]

# %% [markdown]
# ### Clickable links

# %%
def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

df_sorted_rating.style.format({'Ссылка': make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Тренер</th>        <th class="col_heading level0 col1" >Количество голосов</th>        <th class="col_heading level0 col2" >Должность</th>        <th class="col_heading level0 col3" >Ссылка</th>        <th class="col_heading level0 col4" >Клубы</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row0" class="row_heading level0 row0" >547</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row0_col0" class="data row0 col0" >Равиль Сафин</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row0_col1" class="data row0 col1" >75</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row0_col2" class="data row0 col2" >Персональный тренер тренажерного зала</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/ravil-safin/">https://www.worldclass.ru/trainers/ravil-safin/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row0_col4" class="data row0 col4" >['Метрополис']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row1" class="row_heading level0 row1" >897</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row1_col0" class="data row1 col0" >Юсуфи Ясин</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row1_col1" class="data row1 col1" >60</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row1_col2" class="data row1 col2" >Мастер-тренер тренажерного зала</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/yasin-yusufi/">https://www.worldclass.ru/trainers/yasin-yusufi/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row1_col4" class="data row1 col4" >['Метрополис']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row2" class="row_heading level0 row2" >90</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row2_col0" class="data row2 col0" >Егор Глазатов</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row2_col1" class="data row2 col1" >58</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row2_col2" class="data row2 col2" >Супервайзер тренажерного зала. Мастер-тренер тренажёрного зала </td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/glazatov-egor-valentinovich/">https://www.worldclass.ru/trainers/glazatov-egor-valentinovich/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row2_col4" class="data row2 col4" >['Оружейный']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row3" class="row_heading level0 row3" >491</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row3_col0" class="data row3 col0" >Мария Чернобай</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row3_col1" class="data row3 col1" >51</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row3_col2" class="data row3 col2" >Персональный тренер групповых программ, персональный тренер программ Mind&Body</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/chernobay-mariya/">https://www.worldclass.ru/trainers/chernobay-mariya/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row3_col4" class="data row3 col4" >['Капитолий']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row4" class="row_heading level0 row4" >1507</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row4_col0" class="data row4 col0" >Анастасия Гадалина</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row4_col1" class="data row4 col1" >48</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row4_col2" class="data row4 col2" >Персональный тренер водных программ</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/gadalina-anastasiya-alekseevna/">https://www.worldclass.ru/trainers/gadalina-anastasiya-alekseevna/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row4_col4" class="data row4 col4" >['Щелковский']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row5" class="row_heading level0 row5" >951</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row5_col0" class="data row5 col0" >Карина Соколова</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row5_col1" class="data row5 col1" >47</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row5_col2" class="data row5 col2" >Персональный тренер групповых программ</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row5_col3" class="data row5 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/karina-sokolova/">https://www.worldclass.ru/trainers/karina-sokolova/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row5_col4" class="data row5 col4" >['Центр']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row6" class="row_heading level0 row6" >546</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row6_col0" class="data row6 col0" >Татьяна Яковлева</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row6_col1" class="data row6 col1" >45</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row6_col2" class="data row6 col2" >Персональный тренер тренажерного зала</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row6_col3" class="data row6 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/tatyana-yakovleva/">https://www.worldclass.ru/trainers/tatyana-yakovleva/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row6_col4" class="data row6 col4" >['Атлантик Сити']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row7" class="row_heading level0 row7" >234</th>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row7_col0" class="data row7 col0" >Ольга Соловьева</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row7_col1" class="data row7 col1" >42</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row7_col2" class="data row7 col2" >Мастер-тренер тренажерного зала</td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row7_col3" class="data row7 col3" ><a target="_blank" href="https://www.worldclass.ru/trainers/olga-berdyugina/">https://www.worldclass.ru/trainers/olga-berdyugina/</a></td>
#                         <td id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6row7_col4" class="data row7 col4" >['Митино']</td>
#             </tr>
#             <tr>
#                         <th id="T_94a9cce8_e0ae_11eb_8c72_c0e4349370d6level0_row8" class="row_heading level

# %% [markdown]
# ## Saving to .csv

# %%
df.to_csv('world_class_trainers.csv')
